# %% [markdown]
# Analysis of financial statement

# %% [markdown]
# References
# - https://finance.yahoo.com/news/read-analyze-balance-sheet-203413491.html
# - [yahoo_fin documentation](http://theautomatic.net/yahoo_fin-documentation)
#   - https://www.youtube.com/watch?v=Y0oOpMEFTyo&list=PL1EfVfbD6djHHxTzicLzdX5jzH0wEgDs7&index=2&ab_channel=AutomaticSource

# %%
import yahoo_fin.stock_info as yf

# %%
ticker = "AC.TO"
balance_sheet = yf.get_balance_sheet(ticker, yearly=False)

# %%
# balance_sheet

# %%
"""
Balance sheet:


Things to look at
- Quick ratio. 
- book value > market cap
"""

# %%
def get_quick_ratio(cash, )

# %%
balance_sheet = balance_sheet.T.sort_values("endDate")

# %%
balance_sheet.T
# Out:
# endDate                        2021-09-30   2021-12-31   2022-03-31  \
# Breakdown
# intangibleAssets               1095000000   1080000000   1069000000
# capitalSurplus                  102000000    104000000    105000000
# totalLiab                     30155000000  30605000000  30883000000
# totalStockholderEquity          145000000      9000000  -1159000000
# otherCurrentLiab               2793000000   3347000000   4535000000
# totalAssets                   30300000000  30614000000  29724000000
# commonStock                    2734000000   2735000000   2737000000
# otherCurrentAssets               92000000    253000000    199000000
# retainedEarnings              -2653000000  -2785000000  -3970000000
# otherLiab                      8339000000   8170000000   7744000000
# goodWill                       3273000000   3273000000   3273000000
# treasuryStock                   -38000000    -45000000    -31000000
# otherAssets                    3243000000   4364000000   2743000000
# ...
